# %%
       with open(r"C:\Users\verma\PycharmProjects\PythonProject\PythonEssentials_pluralsight\notes.txt",'r',encoding="utf-8") as file:
            content = file.read()
            print(content)
# Out:
# OOP = Object-Oriented Programming
# JSON = JavaScript O Notation
# ML = Machine Learning

# %%
    for i in content.split("\n"):
        abbreviation = i.split("=")[0]
        full_name = i.split("=")[1]
    diction= {abbreviation:full_name}
    usr_input = input("Enter the abbreviation: ")
    for x in diction.keys():
        if usr_input == x:
            print(diction["x"])
